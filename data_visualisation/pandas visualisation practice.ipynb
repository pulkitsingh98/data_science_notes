# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df2 = pd.read_csv('df2')

# %%
sns.set_style('darkgrid')

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist',bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
 df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
 df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1) 
'''
here x=df1.index is not written as now in updated version of pandas 
the plot will automatically define the x axis from the dataframe
'''
# Out:
# '\nhere x=df1.index is not written as now in updated version of pandas \nthe plot will automatically define the x axis from the dataframe\n'

# %%
df1.plot.scatter(x='A',y='B',c='C')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50,edgecolor='black')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
